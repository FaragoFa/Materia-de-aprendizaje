# %% [markdown]
# <a href="https://colab.research.google.com/github/FaragoFa/Materia-de-aprendizaje/blob/master/CancerMama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cargo el dataset de canciones

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/emmanueliarussi/DataScienceCapstone/master/3_MidtermProjects/ProjectBCD/data/data.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# Como tengo mas cantidad de casos benignos que malignos, balanceo el dataset para mejorar el resultado:

# %%
import numpy as np

# eliminar datos benignos aleatorios
total_benignos = df["diagnosis"].value_counts()["B"] 
total_malignos = df["diagnosis"].value_counts()["M"]
to_remove = np.random.choice(df[df['diagnosis']=="B"].index, 
                             size=total_benignos-total_malignos,
                             replace=False)
df = df.drop(to_remove) # remove
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# Transformo las caracteristicas no numericas para poder trabajar con ellas:

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
df["diagnosis"] = labelEncoder.fit_transform(df["diagnosis"])
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# Filtro las caracteristicas innecesarias

# %%
print(list(df.columns))
del df['Unnamed: 32']
df
# Out:
# ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32']
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# ...

# %% [markdown]
# Especifico caracteristicas a entrenar y target

# %%
x = df[['id', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']]
y = df['diagnosis']

# %% [markdown]
# Separo el dataset en datos para entrenar (80%) y en datos para testear (20%) el modelo

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# Escalo las muestras y los targets para ayudar en el entrenamiento

# %%
from sklearn.preprocessing import scale
x = scale(x)   
y = scale(y)

# %% [markdown]
# Creo y entreno el modelo

# %%
from sklearn.ensemble import RandomForestRegressor
modelo = RandomForestRegressor()    # Cargar el tipo de modelo a usar
modelo.fit(xtrain, ytrain)          # Entrenar el modelo con los datos preparados
# Out:
# RandomForestRegressor()

# %% [markdown]
# Obtengo el Score

# %%
score1 = modelo.score(xtest, ytest)    
print("Score:", score1)
# Out:
# Score: 0.7772068106312292

# %% [markdown]
# Testeo

# %%
ypred = modelo.predict(xtest)       # Probar el modelo entrenado usando los datos de testeo

# %% [markdown]
# Obtengo el error comparando los targets originales del conjunto de datos de testeo y los targets predichos por el modelo entrenado

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest, ypred)  # Error medio cuadrático
print("MSE: ", mse)
print()
# Out:
# MSE:  0.055690588235294124

# %% [markdown]
# Como se puede ver el resultado obtenido es muy bueno ya que clasifica muy bien los casos benignos y malignos. Tambien el error medio cuadratico es muy bueno.
